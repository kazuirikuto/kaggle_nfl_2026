# %% [markdown]
# # Nfl Big Data Bowl 2026 PredictionStarter notebook created via `scripts/setup_competition.py`.- Competition: https://www.kaggle.com/competitions/nfl-big-data-bowl-2026-prediction- Created: 2025-11-18 13:22 UTCReplace the sections below with your own workflow before exporting the final submission.

# %% [markdown]
# ## 1. Setup

# %%
import osimport pathlibimport numpy as npimport pandas as pdDATA_DIR = pathlib.Path('../data/raw')print('Files:', sorted(p.name for p in DATA_DIR.glob('*')))

# %% [markdown]
# ## 2. Load Data

# %%
# Example:# train = pd.read_csv(DATA_DIR / 'train.csv')# test = pd.read_csv(DATA_DIR / 'test.csv')train = Nonetest = None

# %% [markdown]
# ## 3. Modeling

# %%
# TODO: build model here

# %% [markdown]
# ## 4. Submission

# %%
# submission = pd.DataFrame({#     'Id': test['Id'],#     'Target': predictions,# })# submission.to_csv('../submissions/submission.csv', index=False)print('Save your submission to ../submissions before uploading to Kaggle.')
